# %% [markdown]
# # Test Colab

# %%
print ("hello world") 
import matplotlib.pyplot as plt
x={1: [1,3], 2: 'fg', 3:['dfg@$']}
print (x)
mydict = {'one': 1, 'two': 2, 'three': 3}
mykeys = ['three', 'one']
[mydict[x] for x in mykeys]
# Out:
# hello world
# {1: [1, 3], 2: 'fg', 3: ['dfg@$']}
# [3, 1]

# %%
from pandas import DataFrame
from fastai import *
df = DataFrame(list(mydict.items()),columns = ['Products','Prices'])

print (df)
# Out:
#   Products  Prices
# 0      one       1
# 1      two       2
# 2    three       3

# %% [markdown]
# # Show infomraiton on Google Map, GMAPS API

# %%
import gmaps

# %%
import gmaps.datasets

# %%
import IPython

# %%
gmaps.configure(api_key='')


earthquake_df=gmaps.datasets.load_dataset_as_df('earthquakes')
earthquake_df.shape
# Out:
# (8604, 3)

# %%
import gmaps
import ipywidgets as widgets

gmaps.configure(api_key="AIzaSyDW-kFFRC7ywmTHFYgRFgIkG0LiXx5BM7s")

#code where I get the dataframe fooDF which contains, among others, cols 'latitude' and 'longitude'>

locations = locations
weights = weights
fig = gmaps.figure()
fig = gmaps.figure(map_type='TERRAIN')
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
embed_minimal_html('export.html', views=[fig])

IPython.display.HTML(filename='export.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4f1c4ee2fd0c> in <module>()
# ----> 1 import gmaps
#       2 import ipywidgets as widgets
#       3
#       4 gmaps.configure(api_key="AIzaSyDW-kFFRC7ywmTHFYgRFgIkG0LiXx5BM7s")
#       5
#
# ModuleNotFoundError: No module named 'gmaps'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from ipywidgets.embed import embed_minimal_html

locations=earthquake_df[['latitude','longitude']]
weights= earthquake_df['magnitude']
fig=gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations,weights=weights))
fig
embed_minimal_html('export.html', views=[fig])

import IPython
IPython.display.HTML(filename='export.html')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
fig=gmaps.figure(map_type='SATELLITE')
embed_minimal_html('export.html', views=[fig])

IPython.display.HTML(filename='export.html')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
locations= [(51.5,0.1),(51.7,0.2),(51.4,-0.2),(51.49,0.1)]
heatmap_layer= gmaps.heatmap_layer(locations)
fig.add_layer(heatmap_layer)
fig = gmaps.figure()
embed_minimal_html('export.html', views=[fig])

IPython.display.HTML(filename='export.html')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
new_york_coordinates= (40.75, -74.09)
fig=gmaps.figure(center=new_york_coordinates, zoom_level=10,map_type='HYBRID')
embed_minimal_html('export.html', views=[fig])
IPython.display.HTML(filename='export.html')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
